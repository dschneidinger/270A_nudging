# %% [markdown]
# We aim to solve the vlasov equation in 1D3V I think
# $$\frac{\partial f_\alpha}{\partial t} + \mathbf{v}_\alpha \cdot \nabla f_\alpha - q_\alpha(\mathbf{E} + \mathbf{v}_\alpha \times \mathbf{B}) \cdot \frac{\partial f_\alpha}{\partial \mathbf{p}} = 0$$
#
# Follow [this](https://www.particleincell.com/2018/intro-to-vlasov-solvers/) tutorial
