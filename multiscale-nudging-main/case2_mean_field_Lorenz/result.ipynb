# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("./simulation/data/mv_sim_seed0.npz")
m = data["means"]

print(m.shape)  # 应该是 (n_steps+1, 3)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.plot(m[:1000, 0], m[:1000, 1], m[:1000, 2], lw=1.5)
data = np.load("./assimilation/data_lambda_1e_3/xyz_da_kdenudge_3d_seed0.npz")
mx = data["mx_est"]
my = data["my_est"]
mz = data["mz_est"]
ax.plot(mx, my, mz, lw=1.5)

data = np.load("./assimilation/data_lambda_1e_4/xyz_da_kdenudge_3d_seed0.npz")
mx = data["mx_est"]
my = data["my_est"]
mz = data["mz_est"]
ax.plot(mx, my, mz, lw=1.5)

data = np.load("./assimilation/data_lambda_1e_5/xyz_da_kdenudge_3d_seed0.npz")
mx = data["mx_est"]
my = data["my_est"]
mz = data["mz_est"]
ax.plot(mx, my, mz, lw=1.5)

ax.set_xlabel("m_x")
ax.set_ylabel("m_y")
ax.set_zlabel("m_z")
plt.show()
# Out:
# (10001, 3)

# %%
data = np.load("./simulation/data/mv_sim_seed0.npz")
m = data["means"]
plt.plot(m[:,0])

# %%
data = np.load("./assimilation/data_lambda_0/xyz_da_kdenudge_3d_seed0.npz")
mx = data["mx_est"]
my = data["my_est"]
mz = data["mz_est"]

print(m.shape)  # 应该是 (n_steps+1, 3)

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.plot(m[:, 0], m[:, 1], m[:, 2], lw=1.5)
ax.plot(mx[:], my[:], mz[:], lw=1.5)

ax.set_xlabel("m_x")
ax.set_ylabel("m_y")
ax.set_zlabel("m_z")
plt.show()
# Out:
# (10001, 3)

# %%
data = np.load("./simulation/data/mv_sim_seed0.npz")
m = data["means"]
plt.plot(m[:1000,1])
data = np.load("./assimilation/data_lambda_0/xyz_da_kdenudge_3d_seed0.npz")
my = data["my_est"]
plt.plot(my[:1000]);

# %%
data = np.load("./simulation/data/mv_sim_seed0.npz")
x = data["y_paths"]
plt.plot(np.var(x[:1000,],axis=1))
data = np.load("./assimilation/data_lambda_1e_3/xyz_da_kdenudge_3d_seed0.npz")
# print(data.keys())
# mx = data["my_est"]
# plt.plot(np.var(x[:1000,],axis=1))

# %%
x.shape
# Out:
# (10001, 1000)

# %%
data = np.load("./simulation/data/mv_sim_seed0.npz")
m = data["means"]
plt.plot(m[:1000,0])
data = np.load("./assimilation/data_lambda_1e_4/xyz_da_kdenudge_3d_seed0.npz")
mx = data["my_est"]
plt.plot(mx[:1000]);

# %%
data = np.load("./simulation/data/mv_sim_seed0.npz")
m = data["means"]
plt.plot(m[:1000,0])
data = np.load("./assimilation/data_lambda_1e_5/xyz_da_kdenudge_3d_seed0.npz")
mx = data["my_est"]
plt.plot(mx[:1000]);
data = np.load("./simulation/data/mv_sim_seed0.npz")
m = data["means"]
plt.plot(m[:1000,1])
data = np.load("./assimilation/data_lambda_1e_5/xyz_da_kdenudge_3d_seed0.npz")
my = data["my_est"]
plt.plot(my[:1000]);
data = np.load("./simulation/data/mv_sim_seed0.npz")
m = data["means"]
plt.plot(m[:1000,2])
data = np.load("./assimilation/data_lambda_1e_5/xyz_da_kdenudge_3d_seed0.npz")
mz = data["mz_est"]
plt.plot(mz[:1000]);
